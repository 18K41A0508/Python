# %%
year=int(input())
if year%12==0:
  print("monkey")
elif year%12==1:
  print("Rooster")
elif year%12==2:
  print("Dog")  
elif year%12==3:
  print("Pig")  
elif year%12==4:
  print("rat")  
elif year%12==5:
  print("ox")  
elif year%12==6:
  print("tiger")  
elif year%12==7:
  print("rabbit")  
elif year%12==8:
  print("dragon")  
elif year%12==9:
  print("snake")  
elif year%12==10:
  print("horse")  
else:
  print("sheep")
# Out:
# 0
# monkey

# %%
from google.colab import drive
drive.mount('/content/drive')
