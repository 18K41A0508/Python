# %%
a=["Stalls","Circle","UpperClass","box"]
s=input("Type of seat:")
pm=input("Payment mode:")
c="cash"
if pm==c:
  if s in a[0]:
    discount=625*(0.1)
    b=625-discount
  elif s in a[1]:
    discount=750*(0.1)
    b=750-discount
  elif s in a[2]:
    discount=850*(0.1)
    b=850-discount
  else:
    discount=1000*(0.1)
    b=1000-discount
else:
  if s in a[0]:
    discount=625*(0.05)
    b=625-discount
  elif s in a[1]:
    discount=750*(0.05)
    b=750-discount
  elif s in a[2]:
    discount=850*(0.05)
    b=850-dis
  else:
    discount=1000*(0.05)
    b=1000-discount
print(b)
# Out:
# Type of seat:Circle
# Payment mode:cash
# 675.0
